% %%
% small image
imshow(randn(100,100))

% %%
% let's change the data range
imshow(randn(100,100), [-10 10])

% %%
% let's try automatic range and different size
imshow(randn(100,200), [])

% %%
% let's try some crushed blacks
imshow(randn(100,200), [0 5])

% %%
% and some clipped whites
imshow(randn(100,200), [-5 1])

% %%
% and a color image
a = imread('test.png');
size(a)
imshow(a(271:410,101:500,:))
% Out:
% ans =
%
%     900   1200      3

% %%
%plot --size 300,300 --format svg
% regular graph
x = linspace(0,2*pi,100);
plot(x, sin(x))

% %%
%plot --size 300,300 --format svg
plot(x, sin(x))

% %%
%plot --size 300,300 --format png
plot(x, sin(x))

% %%
tx = ty = linspace (-8, 8, 41)';
[xx, yy] = meshgrid (tx, ty);
r = sqrt (xx .^ 2 + yy .^ 2) + eps;
tz = sin (r) ./ r;
mesh (tx, ty, tz);
